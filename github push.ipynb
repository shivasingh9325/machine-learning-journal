# %% [markdown]
# # git pull origin main --rebase
# # git add "Day X"
# # git commit -m "Day X"
# # git push

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\SHIVA\\ML shiva'

# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '15 CSV',
#  '16 JSON, SQL',
#  'Untitled.ipynb']

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	deleted:    15 CSV/.ipynb_checkpoints/15 CSV-checkpoint.ipynb
# 	deleted:    15 CSV/.ipynb_checkpoints/IPL Matches 2008-2020-checkpoint.csv
# 	deleted:    15 CSV/.ipynb_checkpoints/aug_train-checkpoint.csv
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.gitignore
# 	.ipynb_checkpoints/
# 	15 CSV/.ipynb_checkpoints/
# 	16 JSON, SQL/
# 	Untitled.ipynb

# %%
git pull origin main --rebase
# Out:
#   Cell In[8], line 1
#     git pull origin main --rebase
#         ^
# SyntaxError: invalid syntax
